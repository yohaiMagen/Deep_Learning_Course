# %%
#imports
import matplotlib.pyplot as plt
import numpy as np

# %%
home_dir = './EX2_data/fddb/'
with open(home_dir + 'FDDB-folds/FDDB-fold-01.txt') as f:
    paths = f.readlines()
imgs = []
for path in paths:
    imgs.append(imread(home_dir + 'images/' + path[:-1] + '.jpg'))

# %%
fig, axarr = plt.subplots(5, 5)
for ax, idx in zip(axarr.flatten(), np.random.randint(0, len(imgs), 25)):
    ax.imshow(imgs[idx])

# %%
tw_net_fcn = nn.Sequential(nn.Conv2d(C, conv_12_dim, conv_12_size, padding=conv_12_pad),
                           nn.MaxPool2d(kernel_size=max_pool_size, stride=max_pool_stride, padding=max_pool_pad),
                           nn.ReLU(),
                           nn.Conv2d(in_channels=conv_12_dim, out_channels=fc_12_size, kernel_size=L // 2),
                           nn.ReLU(),
                           nn.Conv2d(in_channels=fc_12_size, out_channels=output_dim, kernel_size=1)
                           )
tw_net_fcn.load_state_dict(torch.load('./tw_net_fcn.pth'))
tw_net_fcn.eval()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-ff81f2010ad9> in <module>()
# ----> 1 tw_net_fcn = nn.Sequential(nn.Conv2d(C, conv_12_dim, conv_12_size, padding=conv_12_pad),
#       2                            nn.MaxPool2d(kernel_size=max_pool_size, stride=max_pool_stride, padding=max_pool_pad),
#       3                            nn.ReLU(),
#       4                            nn.Conv2d(in_channels=conv_12_dim, out_channels=fc_12_size, kernel_size=L // 2),
#       5                            nn.ReLU(),
#
# NameError: name 'C' is not defined

# %%
x = np.abs(np.arange(-10, 12, 2, dtype=np.float32))
X, Y = np.meshgrid(x, x)

# %%
iou = ((12 - X) * (12 - Y)) / (2 * 12**2 - ((12 - X) * (12 - Y)))

# %%
plt.imshow(iou)
plt.colorbar()
